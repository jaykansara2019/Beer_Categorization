# %%
# Import dependencies 
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# Creating filepaths to csv
filepath_beers = os.path.join('beers.csv')
filepath_breweries = os.path.join('breweries.csv')
filepath_reviews = os.path.join('reviews.csv')

# %%
# Creating dataframe for beers and filtering for the US
beers_df = pd.read_csv(filepath_beers)
beers_df
# Out:
#             id                                  name  brewery_id state  \
# 0       202522                        Olde Cogitator        2199    CA
# 1        82352  Konrads Stout Russian Imperial Stout       18604   NaN
# 2       214879                        Scottish Right       44306    IN
# 3       320009               MegaMeow Imperial Stout        4378    WA
# 4       246438                       Peaches-N-Cream       44617    PA
# ...        ...                                   ...         ...   ...
# 358868  267703              Collective Project: Gose       32763    ON
# 358869  300013                                Tripel       50238   NaN
# 358870  187618                                 RIPTA       34665    RI
# 358871  283124                           Rumble Fish       29238    MI
# 358872  267484                         Joie De Vivre       25032    CA
#
#        country                    style           availability   abv  \
# 0           US    English Oatmeal Stout               Rotating   7.3
# 1           NO   Russian Imperial Stout               Rotating  10.4
# 2           US             Scottish Ale             Year-round   4.0
# 3           US  American Imperial Stout                 Winter   8.7
# 4           US       American Cream Ale               Rotating   5.1
# ...        ...                      ...                    ...   ...
# 358868      CA             Leipzig Gose  Limited (brewed once)   5.0
# 358869      BE           Belgian Tripel             Year-round   8.0
# 358870      US           Belgian Tripel               Rotating   9.5
# 358871      US    American Imperial IPA               Rotating   8.3
# 358872      US           Belgian Saison  Limited (brewed once)   6.6
#
#                                                     notes retired
# 0                                  No notes at this time.       f
# 1                                  No notes at this time.       f
# 2                                  No notes at this time.       t
# 3                                    Every time this year       f
# 4                                  No notes at this time.       f
# ...                                                   ...     ...
# 358868  Our Gose is an unfiltered wheat beer made with...       t
# 358869                             No notes at this time.       f
# 358870                             No notes at this time.       f
# 358871                             No notes at this time.       f
# 358872                             No notes at this time.       t
#
# [358873 rows x 10 columns]

# %%
# Creating dataframe for breweries
breweries_df = pd.read_csv(filepath_breweries)
breweries_df
# Out:
#           id                                  name              city state  \
# 0      19730                       Brouwerij Danny         Erpe-Mere   NaN
# 1      32541           Coachella Valley Brewing Co    Thousand Palms    CA
# 2      44736                      Beef 'O' Brady's        Plant City    FL
# 3      23372                Broadway Wine Merchant     Oklahoma City    OK
# 4      35328  Brighton Beer Dispensary (DUPLICATE)          Brighton   GB2
# ...      ...                                   ...               ...   ...
# 50342   1430                Blagodarnensky Brewery        Blagodarny   NaN
# 50343  23267                                Eataly       Torino (TO)   NaN
# 50344  32352                   Frites - Quarry Bay  Hong Kong Island   NaN
# 50345  20047           Forest City Wines & Spirits        Middletown    CT
# 50346  13986                 Landmark Beer Company          Syracuse    NY
#
#       country                                              notes  \
# 0          BE                             No notes at this time.
# 1          US                             No notes at this time.
# 2          US                             No notes at this time.
# 3          US                             No notes at this time.
# 4          GB  Duplicate of https://www.beeradvocate.com/beer...
# ...       ...                                                ...
# 50342      RU                             No notes at this time.
# 50343      IT  Big gourmet market, with a beer store and a be...
# 50344      HK  Located on the Ground Floor of Oxford House in...
# 50345      US                             No notes at this time.
# 50346      US                             No notes at this time.
#
#                           types
# 0                       Brewery
# 1      Brewery, Bar, Beer-to-go
# 2                   Bar, Eatery
# 3                         Store
# 4                   Bar, Eatery
# ...                         ...
# 50342                   Brewery
# 50343   Bar, Eatery, Beer-to-go
# 50344               Bar, Eatery
# 50345                     Store
# 50346                   Brewery
#
# [50347 rows x 7 columns]

# %%
# change column names
beers_df.rename(columns = {'id':'beer_id',                       
                           'name':'beer_name', 
                           'state':'state_beer', 
                           'country':'country_beer', 
                           'notes':'beer_notes'}, inplace = True)
breweries_df.rename(columns = {'id':'brewery_id',                       
                           'name':'brewery_name', 
                           'state':'state_brewery', 
                           'country':'country_brewery', 
                           'notes':'brewery_notes'}, inplace = True)

# %%
# Creating dataframe for reviews
reviews_df = pd.read_csv(filepath_reviews)
reviews_df
# Out:
#          beer_id          username        date  \
# 0         271781      bluejacket74  2017-03-17
# 1         125646           _dirty_  2017-12-21
# 2         125646           CJDUBYA  2017-12-21
# 3         125646   GratefulBeerGuy  2017-12-20
# 4         125646          LukeGude  2017-12-20
# ...          ...               ...         ...
# 9073123   104824            CTJman  2014-06-08
# 9073124   104824  IMSPEAKNOENGLISH  2014-06-06
# 9073125   104824          twizzard  2014-06-05
# 9073126   104824        bootdown21  2014-06-04
# 9073127   104824           Brensol  2014-06-01
#
#                                                       text  look  smell  \
# 0           750 ml bottle, 2016 vintage, bottle #304 of...  4.00   4.00
# 1                                                           4.50   4.50
# 2                                                           4.75   4.75
# 3           0% 16 oz can. Funny story: As I finally wal...  4.75   4.75
# 4           Classic TH NEIPA. Overflowing head and bouq...  4.25   4.50
# ...                                                    ...   ...    ...
# 9073123                                                      NaN    NaN
# 9073124                                                      NaN    NaN
# 9073125                                                      NaN    NaN
# 9073126                                                      NaN    NaN
# 9073127                                                      NaN    NaN
#
#          taste  feel  overall  score
# 0         4.00  4.25     4.00   4.03
# 1         4.50  4.50     4.50   4.50
# 2         4.75  4.75     4.75   4.75
# 3         4.50  4.50     4.50   4.58
# 4         4.25  4.25     4.25   4.31
# ...        ...   ...      ...    ...
# 9073123    NaN   NaN      NaN   4.00
# 9073124    NaN   NaN      NaN   5.00
# 9073125    NaN   NaN      NaN   5.00
# 9073126    NaN   NaN      NaN   4.50
# 9073127    NaN   NaN      NaN   4.75
#
# [9073128 rows x 10 columns]

# %%
# choose only US breweries from beer table
beers_df = beers_df[beers_df.country_beer == 'US']
beers_df
# Out:
#         beer_id                                beer_name  brewery_id  \
# 0        202522                           Olde Cogitator        2199
# 2        214879                           Scottish Right       44306
# 3        320009                  MegaMeow Imperial Stout        4378
# 4        246438                          Peaches-N-Cream       44617
# 6        108605                              Icon Sender       22598
# ...         ...                                      ...         ...
# 358865   258269  Brewers Select #019 High Pressure Lager       28281
# 358867   146613                        American Pale Ale       36926
# 358870   187618                                    RIPTA       34665
# 358871   283124                              Rumble Fish       29238
# 358872   267484                            Joie De Vivre       25032
#
#        state_beer country_beer                    style  \
# 0              CA           US    English Oatmeal Stout
# 2              IN           US             Scottish Ale
# 3              WA           US  American Imperial Stout
# 4              PA           US       American Cream Ale
# 6              CA           US           American Lager
# ...           ...          ...                      ...
# 358865         WA           US           American Lager
# 358867         WI           US  American Pale Ale (APA)
# 358870         RI           US           Belgian Tripel
# 358871         MI           US    American Imperial IPA
# 358872         CA           US           Belgian Saison
#
#                  availability  abv              beer_notes retired
# 0                    Rotating  7.3  No notes at this time.       f
# 2                  Year-round  4.0  No notes at this time.       t
# 3                      Winter  8.7    Every time this year       f
# 4                    Rotating  5.1  No notes at this time.       f
# 6                  Year-round  5.6  No notes at this time.       f
# ...                       ...  ...                     ...     ...
# 358865               Rotating  4.5  No notes at this time.       f
# 358867               Rotating  NaN  No notes at this time.       t
# 358870               Rotating  9.5  No notes at this time.       f
# 358871               Rotating  8.3  No notes at this time.       f
# 358872  Limited (brewed once)  6.6  No notes at this time.       t
#
# [265461 rows x 10 columns]

# %%
# filter only US breweries from breweries table
breweries_df = breweries_df[breweries_df.country_brewery == 'US']
breweries_df
# Out:
#        brewery_id                 brewery_name            city state_brewery  \
# 1           32541  Coachella Valley Brewing Co  Thousand Palms            CA
# 2           44736             Beef 'O' Brady's      Plant City            FL
# 3           23372       Broadway Wine Merchant   Oklahoma City            OK
# 5           31561               Teddy's Tavern         Seattle            WA
# 9           41278                The Other End          Destin            FL
# ...           ...                          ...             ...           ...
# 50338        3124  Abington Ale House & Grille        Abington            MA
# 50339       30980           Zipline Brewing Co         Lincoln            NE
# 50341       24375            The Copper Kettle        Soldotna            AK
# 50345       20047  Forest City Wines & Spirits      Middletown            CT
# 50346       13986        Landmark Beer Company        Syracuse            NY
#
#       country_brewery           brewery_notes                     types
# 1                  US  No notes at this time.  Brewery, Bar, Beer-to-go
# 2                  US  No notes at this time.               Bar, Eatery
# 3                  US  No notes at this time.                     Store
# 5                  US  No notes at this time.           Bar, Beer-to-go
# 9                  US  No notes at this time.               Bar, Eatery
# ...               ...                     ...                       ...
# 50338              US  No notes at this time.               Bar, Eatery
# 50339              US  No notes at this time.  Brewery, Bar, Beer-to-go
# 50341              US  No notes at this time.                  Homebrew
# 50345              US  No notes at this time.                     Store
# 50346              US  No notes at this time.                   Brewery
#
# [34693 rows x 7 columns]

# %%
# Merge beer and brewery datasets
beer_data_complete_df = pd.merge(beers_df, breweries_df, how="left", on=["brewery_id", "brewery_id"])
beer_data_complete_df
# Out:
#         beer_id                                beer_name  brewery_id  \
# 0        202522                           Olde Cogitator        2199
# 1        214879                           Scottish Right       44306
# 2        320009                  MegaMeow Imperial Stout        4378
# 3        246438                          Peaches-N-Cream       44617
# 4        108605                              Icon Sender       22598
# ...         ...                                      ...         ...
# 265456   258269  Brewers Select #019 High Pressure Lager       28281
# 265457   146613                        American Pale Ale       36926
# 265458   187618                                    RIPTA       34665
# 265459   283124                              Rumble Fish       29238
# 265460   267484                            Joie De Vivre       25032
#
#        state_beer country_beer                    style  \
# 0              CA           US    English Oatmeal Stout
# 1              IN           US             Scottish Ale
# 2              WA           US  American Imperial Stout
# 3              PA           US       American Cream Ale
# 4              CA           US           American Lager
# ...           ...          ...                      ...
# 265456         WA           US           American Lager
# 265457         WI           US  American Pale Ale (APA)
# 265458         RI           US           Belgian Tripel
# 265459         MI           US    American Imperial IPA
# 265460         CA           US           Belgian Saison
#
#                  availability  abv              beer_notes retired  \
# 0                    Rotating  7.3  No notes at this time.       f
# 1                  Year-round  4.0  No notes at this time.       t
# 2                      Winter  8.7    Every time this year       f
# 3                    Rotating  5.1  No notes at this time.       f
# 4                  Year-round  5.6  No notes at this time.       f
# ...                       ...  ...                     ...     ...
# 265456               Rotating  4.5  No notes at this time.       f
# 265457               Rotating  NaN  No notes at this time.       t
# 265458               Rotating  9.5  No notes at this time.       f
# 265459               Rotating  8.3  No notes at this time.       f
# 265460  Limited (brewed once)  6.6  No notes at this time.       t
#
#                       brewery_name                    city state_brewery  \
# 0              Main Street Brewery              Pleasanton            CA
# 1                    Byway Brewing                 Hammond            IN
# 2       Georgetown Brewing Company                 Seattle            WA
# 3              Mad Princes Brewing              Doylestown            PA
# 4       Cismontane Brewing Company  Rancho Santa Margarita            CA
# ...                            ...                     ...           ...
# 265456     Kulshan Brewing Company              Bellingham            WA
# 265457     Tornado Brewing Company         Menomonee Falls            WI
# 265458            Brutopia Brewery                Cranston            RI
# 265459    Ore Dock Brewing Company               Marquette            MI
# 265460       Triple Voodoo Brewing           San Francisco            CA
#
#        country_brewery                                      brewery_notes  \
# 0                   US                             No notes at this time.
# 1                   US                             No notes at this time.
# 2                   US                             No notes at this time.
# 3                   US                             No notes at this time.
# 4                   US                             No notes at this time.
# ...                ...                                                ...
# 265456              US                             No notes at this time.
# 265457              US  Beers are brewed at Woodman Brewery in Woodman...
# 265458              US                             No notes at this time.
# 265459              US                             No notes at this time.
# 265460              US                             No notes at this time.
#
#                                    types
# 0                   Brewery, Bar, Eatery
# 1       Brewery, Bar, Eatery, Beer-to-go
# 2                                Brewery
# 3               Brewery, Bar, Beer-to-go
# 4               Brewery, Bar, Beer-to-go
# ...                                  ...
# 265456          Brewery, Bar, Beer-to-go
# 265457              Brewery, Bar, Eatery
# 265458  Brewery, Bar, Eatery, Beer-to-go
# 265459          Brewery, Bar, Beer-to-go
# 265460          Brewery, Bar, Beer-to-go
#
# [265461 rows x 16 columns]

# %%
# Merge beer_final and reviews dataset
beer_reviews_complete_df = pd.merge(beer_data_complete_df, reviews_df, how="left", on=["beer_id", "beer_id"])
beer_reviews_complete_df.head(10)
# Out:
#    beer_id                beer_name  brewery_id state_beer country_beer  \
# 0   202522           Olde Cogitator        2199         CA           US
# 1   214879           Scottish Right       44306         IN           US
# 2   320009  MegaMeow Imperial Stout        4378         WA           US
# 3   246438          Peaches-N-Cream       44617         PA           US
# 4   108605              Icon Sender       22598         CA           US
# 5   108605              Icon Sender       22598         CA           US
# 6   255286      Light Of The Ozarks       11203         AR           US
# 7   253234    Coffee Infused Bitter       46862         WA           US
# 8   253234    Coffee Infused Bitter       46862         WA           US
# 9    15271        Belgian Style Wit        1345         WA           US
#
#                      style availability  abv              beer_notes retired  \
# 0    English Oatmeal Stout     Rotating  7.3  No notes at this time.       f
# 1             Scottish Ale   Year-round  4.0  No notes at this time.       t
# 2  American Imperial Stout       Winter  8.7    Every time this year       f
# 3       American Cream Ale     Rotating  5.1  No notes at this time.       f
# 4           American Lager   Year-round  5.6  No notes at this time.       f
# 5           American Lager   Year-round  5.6  No notes at this time.       f
# 6           American Lager     Rotating  4.3  No notes at this time.       f
# 7           English Bitter     Rotating  3.5  No notes at this time.       f
# 8           English Bitter     Rotating  3.5  No notes at this time.       f
# 9          Belgian Witbier   Year-round  4.5  No notes at this time.       t
#
#    ...                             types      username        date  \
# 0  ...              Brewery, Bar, Eatery           NaN         NaN
# 1  ...  Brewery, Bar, Eatery, Beer-to-go     warpig372  2016-04-12
# 2  ...                           Brewery   NickThePyro  2018-03-16
# 3  ...          Brewery, Bar, Beer-to-go  rolltide8425  2016-08-27
# 4  ...          Brewery, Bar, Beer-to-go  Smarty_Pints  2013-12-29
# 5  ...          Brewery, Bar, Beer-to-go    SocalKicks  2013-12-22
# 6  ...  Brewery, Bar, Eatery, Beer-to-go   kylehay2004  2016-11-04
# 7  ...          Brewery, Bar, Beer-to-go   NickThePyro  2017-04-24
# 8  ...          Brewery, Bar, Beer-to-go      drews240  2017-03-06
# 9  ...              Brewery, Bar, Eatery     zacharius  2004-02-01
#
#                                                 text look smell taste feel  \
# 0                                                NaN  NaN   NaN   NaN  NaN
# 1                                                     NaN   NaN   NaN  NaN
# 2                                                     NaN   NaN   NaN  NaN
# 3                         Exactly what it says it is  NaN   NaN   NaN  NaN
# 4                                                     NaN   NaN   NaN  NaN
# 5                                                     NaN   NaN   NaN  NaN
# 6                                                     NaN   NaN   NaN  NaN
# 7                                                     NaN   NaN   NaN  NaN
# 8                                                     NaN   NaN   NaN  NaN
# 9     Beer poured a light pale yellow. Smell was ...  NaN   NaN   NaN  NaN
#
#   overall  score
# 0     NaN    NaN
# 1     NaN   2.50
# 2     NaN   4.00
# 3     NaN   3.67
# 4     NaN   3.75
# 5     NaN   3.75
# 6     NaN   3.03
# 7     NaN   3.50
# 8     NaN   3.58
# 9     NaN   2.50
#
# [10 rows x 25 columns]

# %%
# Checking if state_beer and state_brewery match
df2 = beer_reviews_complete_df.filter(['state_beer', 'state_brewery'])
df2['match'] = beer_reviews_complete_df['state_beer'] == beer_reviews_complete_df['state_brewery']
df2[beer_reviews_complete_df['state_beer'] == beer_reviews_complete_df['state_brewery']]
df2 = df2[df2.match == False]
df2
# Out:
#         state_beer state_brewery  match
# 1055           NaN           NaN  False
# 1056           NaN           NaN  False
# 4830           NaN           NaN  False
# 5005           NaN           NaN  False
# 7863           NaN           NaN  False
# ...            ...           ...    ...
# 7546503        NaN           NaN  False
# 7546778        NaN           NaN  False
# 7548117        NaN           NaN  False
# 7550107        NaN           NaN  False
# 7550108        NaN           NaN  False
#
# [28711 rows x 3 columns]

# %%
# check NA
df2.isna().sum()
# Out:
# state_beer       28711
# state_brewery    28711
# match                0
# dtype: int64

# %%
#checked retired breweries
beer_reviews_complete_df['retired'].value_counts()
# Out:
# f    6020644
# t    1530149
# Name: retired, dtype: int64

# %%
# remove retired breweries
beer_reviews_complete_df = beer_reviews_complete_df[beer_reviews_complete_df.retired == 'f']
beer_reviews_complete_df
# Out:
#          beer_id                beer_name  brewery_id state_beer country_beer  \
# 0         202522           Olde Cogitator        2199         CA           US
# 2         320009  MegaMeow Imperial Stout        4378         WA           US
# 3         246438          Peaches-N-Cream       44617         PA           US
# 4         108605              Icon Sender       22598         CA           US
# 5         108605              Icon Sender       22598         CA           US
# ...          ...                      ...         ...        ...          ...
# 7550787   187618                    RIPTA       34665         RI           US
# 7550788   187618                    RIPTA       34665         RI           US
# 7550789   187618                    RIPTA       34665         RI           US
# 7550790   187618                    RIPTA       34665         RI           US
# 7550791   283124              Rumble Fish       29238         MI           US
#
#                            style availability  abv              beer_notes  \
# 0          English Oatmeal Stout     Rotating  7.3  No notes at this time.
# 2        American Imperial Stout       Winter  8.7    Every time this year
# 3             American Cream Ale     Rotating  5.1  No notes at this time.
# 4                 American Lager   Year-round  5.6  No notes at this time.
# 5                 American Lager   Year-round  5.6  No notes at this time.
# ...                          ...          ...  ...                     ...
# 7550787           Belgian Tripel     Rotating  9.5  No notes at this time.
# 7550788           Belgian Tripel     Rotating  9.5  No notes at this time.
# 7550789           Belgian Tripel     Rotating  9.5  No notes at this time.
# 7550790           Belgian Tripel     Rotating  9.5  No notes at this time.
# 7550791    American Imperial IPA     Rotating  8.3  No notes at this time.
#
#         retired  ...                             types           username  \
# 0             f  ...              Brewery, Bar, Eatery                NaN
# 2             f  ...                           Brewery        NickThePyro
# 3             f  ...          Brewery, Bar, Beer-to-go       rolltide8425
# 4             f  ...          Brewery, Bar, Beer-to-go       Smarty_Pints
# 5             f  ...          Brewery, Bar, Beer-to-go         SocalKicks
# ...         ...  ...                               ...                ...
# 7550787       f  ...  Brewery, Bar, Eatery, Beer-to-go           rallyr32
# 7550788       f  ...  Brewery, Bar, Eatery, Beer-to-go  PhineasMcClintock
# 7550789       f  ...  Brewery, Bar, Eatery, Beer-to-go            Knapp85
# 7550790       f  ...  Brewery, Bar, Eatery, Beer-to-go            Jwale73
# 7550791       f  ...          Brewery, Bar, Beer-to-go         Blackop555
#
#                date                                               text  look  \
# 0               NaN                                                NaN   NaN
# 2        2018-03-16                                                      NaN
# 3        2016-08-27                         Exactly what it says it is   NaN
# 4        2013-12-29                                                      NaN
# 5        2013-12-22                                                      NaN
# ...             ...                                                ...   ...
# 7550787  2016-02-27                                                     4.75
# 7550788  2016-02-06                                                     3.75
# 7550789  2016-02-06                                                     4.00
# 7550790  2015-08-25     From a grower purchased on 8/23/15 and serv...  4.25
# 7550791  2017-05-23     Pours light copper. Thick, short, off white...   NaN
#
#         smell taste  feel overall  score
# 0         NaN   NaN   NaN     NaN    NaN
# 2         NaN   NaN   NaN     NaN   4.00
# 3         NaN   NaN   NaN     NaN   3.67
# 4         NaN   NaN   NaN     NaN   3.75
# 5         NaN   NaN   NaN     NaN   3.75
# ...       ...   ...   ...     ...    ...
# 7550787  4.25  4.50  4.50    4.50   4.46
# 7550788  3.50  3.75  3.75    3.75   3.69
# 7550789  3.75  3.75  4.00    3.75   3.79
# 7550790  4.00  4.00  4.00    4.00   4.02
# 7550791   NaN   NaN   NaN     NaN   4.29
#
# [6020644 rows x 25 columns]

# %%
beer_reviews_complete_df.columns
# Out:
# Index(['beer_id', 'beer_name', 'brewery_id', 'state_beer', 'country_beer',
#        'style', 'availability', 'abv', 'beer_notes', 'retired', 'brewery_name',
#        'city', 'state_brewery', 'country_brewery', 'brewery_notes', 'types',
#        'username', 'date', 'text', 'look', 'smell', 'taste', 'feel', 'overall',
#        'score'],
#       dtype='object')

# %%
beer_reviews_complete_df.availability.value_counts()
# Out:
#  Year-round                2039718
#  Rotating                  1716265
# Rotating                    709454
# Year-round                  367028
#  Winter                     342352
#  Fall                       288654
#  Summer                     149851
#  Spring                     131552
# Fall                         63246
# Winter                       61191
# Summer                       46555
#  Limited (brewed once)       42047
# Spring                       40298
# Limited (brewed once)        22039
#  Rotating                      211
#  Fall                          122
#  Winter                         59
#  Limited (brewed once)           2
# Name: availability, dtype: int64

# %%
beer_reviews_complete_df = beer_reviews_complete_df[beer_reviews_complete_df.country_beer == 'US']
beer_reviews_complete_df = beer_reviews_complete_df.drop(columns = ['availability', 'beer_notes', 'retired', 'types', 'username', 'date', 'text', 'brewery_notes', 'state_brewery', 'country_brewery'])
#should we drop availability?
beer_reviews_complete_df.head()
beer_reviews_complete_df.isna().sum()
# Out:
# beer_id               0
# beer_name             0
# brewery_id            0
# state_beer        23824
# country_beer          0
# style                 0
# abv               72978
# brewery_name          0
# city              23824
# look            2552818
# smell           2552818
# taste           2552818
# feel            2552818
# overall         2552818
# score             25851
# dtype: int64

# %%
# Remember to reset index
beer_reviews_complete_df = beer_reviews_complete_df.dropna()
beer_reviews_complete_df
# Out:
#          beer_id beer_name  brewery_id state_beer country_beer  \
# 13        265827   Addison       30870         PA           US
# 14        265827   Addison       30870         PA           US
# 15        265827   Addison       30870         PA           US
# 20        138971    Porter       34412         NC           US
# 21        138971    Porter       34412         NC           US
# ...          ...       ...         ...        ...          ...
# 7550786   187618     RIPTA       34665         RI           US
# 7550787   187618     RIPTA       34665         RI           US
# 7550788   187618     RIPTA       34665         RI           US
# 7550789   187618     RIPTA       34665         RI           US
# 7550790   187618     RIPTA       34665         RI           US
#
#                            style  abv       brewery_name        city  look  \
# 13       American Pale Ale (APA)  5.5   La Cabra Brewing      Berwyn  4.25
# 14       American Pale Ale (APA)  5.5   La Cabra Brewing      Berwyn  3.75
# 15       American Pale Ale (APA)  5.5   La Cabra Brewing      Berwyn  4.25
# 20               American Porter  5.3  Dirtbag Ales, LLC  Hope Mills  3.50
# 21               American Porter  5.3  Dirtbag Ales, LLC  Hope Mills  4.00
# ...                          ...  ...                ...         ...   ...
# 7550786           Belgian Tripel  9.5   Brutopia Brewery    Cranston  4.00
# 7550787           Belgian Tripel  9.5   Brutopia Brewery    Cranston  4.75
# 7550788           Belgian Tripel  9.5   Brutopia Brewery    Cranston  3.75
# 7550789           Belgian Tripel  9.5   Brutopia Brewery    Cranston  4.00
# 7550790           Belgian Tripel  9.5   Brutopia Brewery    Cranston  4.25
#
#          smell  taste  feel  overall  score
# 13        4.00   4.00  4.00     4.25   4.07
# 14        3.25   4.00  3.75     3.75   3.73
# 15        4.25   4.25  4.25     4.25   4.25
# 20        3.75   3.75  3.50     3.75   3.71
# 21        4.50   4.50  3.50     4.00   4.27
# ...        ...    ...   ...      ...    ...
# 7550786   4.00   4.00  4.00     4.00   4.00
# 7550787   4.25   4.50  4.50     4.50   4.46
# 7550788   3.50   3.75  3.75     3.75   3.69
# 7550789   3.75   3.75  4.00     3.75   3.79
# 7550790   4.00   4.00  4.00     4.00   4.02
#
# [3413697 rows x 15 columns]

# %%
beer_reviews_complete_df.nunique()
# Out:
# beer_id         71246
# beer_name       64333
# brewery_id       4776
# state_beer         51
# country_beer        1
# style             110
# abv               550
# brewery_name     4732
# city             2039
# look               17
# smell              17
# taste              17
# feel               17
# overall            17
# score             400
# dtype: int64

# %%
beer_reviews_complete_df['style'].value_counts()
# Out:
# American IPA               536962
# American Imperial IPA      363756
# American Imperial Stout    247905
# American Pale Ale (APA)    195807
# Belgian Saison             113467
#                             ...
# American Brut IPA             240
# Russian Kvass                 197
# European Strong Lager         107
# Japanese Rice Lager            32
# Belgian Faro                   10
# Name: style, Length: 110, dtype: int64

# %%
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('IPA', case=False), 'style'] = 'Pale Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Pale', case=False), 'style'] = 'Pale Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('APA', case=False), 'style'] = 'Pale Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Lager', case=False), 'style'] = 'Lager'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Stout', case=False), 'style'] = 'Stout'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Dark Ale', case=False), 'style'] = 'Dark Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Brown Ale', case=False), 'style'] = 'Brown Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Red Ale', case=False), 'style'] = 'Red Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Porter', case=False), 'style'] = 'Porter'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Wild Ale', case=False), 'style'] = 'Wild Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Pilsner', case=False), 'style'] = 'Pilsner'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Pilsener', case=False), 'style'] = 'Pilsner'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Blonde Ale', case=False), 'style'] = 'Blonde Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Strong Ale', case=False), 'style'] = 'Strong Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Dark Mild Ale', case=False), 'style'] = 'Dark Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Black Ale', case=False), 'style'] = 'Dark Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Barleywine', case=False), 'style'] = 'Barleywine'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Saison', case=False), 'style'] = 'Farmhouse Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Farmhouse Ale', case=False), 'style'] = 'Farmhouse Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Lambic', case=False), 'style'] = 'Wild Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Roggenbier', case=False), 'style'] = 'Rye Beer'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Faro', case=False), 'style'] = 'Wild Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Eisbock', case=False), 'style'] = 'Lager'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Sahti', case=False), 'style'] = 'Farmhouse Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('dortmunder', case=False), 'style'] = 'Lager'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('kellerbier', case=False), 'style'] = 'Lager'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Gueuze', case=False), 'style'] = 'Wild Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Wheatwine Ale', case=False), 'style'] = 'Wheatwine Ale'
beer_reviews_complete_df.loc[beer_reviews_complete_df['style'].str.contains('Dark Wheat Ale', case=False), 'style'] = 'Dark Ale'

# %%
beer_style_counts = beer_reviews_complete_df['style'].value_counts()
beer_style_counts
# Out:
# Pale Ale                                       1344748
# Stout                                           514893
# Porter                                          157133
# Lager                                           118129
# Farmhouse Ale                                   114719
# Wild Ale                                        112935
# Red Ale                                          97268
# Brown Ale                                        77639
# Fruit and Field Beer                             63319
# Barleywine                                       61214
# Dark Ale                                         58694
# Pilsner                                          58450
# Belgian Witbier                                  45839
# Strong Ale                                       42948
# Pumpkin Beer                                     38546
# Blonde Ale                                       36405
# German Märzen / Oktoberfest                      31394
# Scotch Ale / Wee Heavy                           29384
# Berliner Weisse                                  27764
# Leipzig Gose                                     27213
# Belgian Tripel                                   26468
# German Hefeweizen                                26098
# Winter Warmer                                    24440
# Herb and Spice Beer                              20451
# Belgian Quadrupel (Quad)                         19493
# German Kölsch                                    19206
# Rye Beer                                         19157
# English Old Ale                                  18664
# English Extra Special / Strong Bitter (ESB)      14810
# American Cream Ale                               14505
# Belgian Dubbel                                   14160
# German Doppelbock                                12060
# German Bock                                      11920
# German Schwarzbier                               11074
# German Maibock                                   10768
# German Helles                                    10550
# German Altbier                                    8798
# French Bière de Garde                             8729
# Scottish Ale                                      8576
# Flanders Oud Bruin                                7597
# California Common / Steam Beer                    5898
# American Malt Liquor                              5892
# Wheatwine Ale                                     5048
# Chile Beer                                        4700
# American Brett                                    4490
# English Bitter                                    4310
# German Weizenbock                                 4076
# Smoke Beer                                        3397
# German Dunkelweizen                               2984
# German Rauchbier                                  2041
# Braggot                                           1323
# German Kristalweizen                              1203
# Scottish Gruit / Ancient Herbed Ale                917
# Low Alcohol Beer                                   787
# Bière de Champagne / Bière Brut                    276
# Russian Kvass                                      197
# Name: style, dtype: int64

# %%
beer_style_counts.plot.density()
plt.xlim(left=0, right=1000000)
# Out:
# (0.0, 1000000.0)

# %%
replace_beer_styles = list(beer_style_counts[beer_style_counts < 10000].index)

# Replace in dataframe
for beer_style in replace_beer_styles:
    beer_reviews_complete_df['style'] = beer_reviews_complete_df['style'].replace(beer_style,"Other")
    
# Check to make sure binning was successful
beer_reviews_complete_df['style'].value_counts()
# Out:
# Pale Ale                                       1344748
# Stout                                           514893
# Porter                                          157133
# Lager                                           118129
# Farmhouse Ale                                   114719
# Wild Ale                                        112935
# Red Ale                                          97268
# Other                                            81239
# Brown Ale                                        77639
# Fruit and Field Beer                             63319
# Barleywine                                       61214
# Dark Ale                                         58694
# Pilsner                                          58450
# Belgian Witbier                                  45839
# Strong Ale                                       42948
# Pumpkin Beer                                     38546
# Blonde Ale                                       36405
# German Märzen / Oktoberfest                      31394
# Scotch Ale / Wee Heavy                           29384
# Berliner Weisse                                  27764
# Leipzig Gose                                     27213
# Belgian Tripel                                   26468
# German Hefeweizen                                26098
# Winter Warmer                                    24440
# Herb and Spice Beer                              20451
# Belgian Quadrupel (Quad)                         19493
# German Kölsch                                    19206
# Rye Beer                                         19157
# English Old Ale                                  18664
# English Extra Special / Strong Bitter (ESB)      14810
# American Cream Ale                               14505
# Belgian Dubbel                                   14160
# German Doppelbock                                12060
# German Bock                                      11920
# German Schwarzbier                               11074
# German Maibock                                   10768
# German Helles                                    10550
# Name: style, dtype: int64

# %%
beer_reviews_complete_df.nunique()
# Out:
# beer_id         71246
# beer_name       64333
# brewery_id       4776
# state_beer         51
# country_beer        1
# style              37
# abv               550
# brewery_name     4732
# city             2039
# look               17
# smell              17
# taste              17
# feel               17
# overall            17
# score             400
# dtype: int64

# %%
fig = plt.figure(figsize = (11,18))
plt.matshow(beer_reviews_complete_df[['abv', 'taste', 'feel', 'look', 'smell']].corr())
plt.show()

# %%
corr_df = beer_reviews_complete_df[['abv', 'taste', 'feel', 'look', 'smell']].corr()
corr_df.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_7096c_row0_col0, #T_7096c_row1_col1, #T_7096c_row2_col2, #T_7096c_row3_col3, #T_7096c_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7096c_row0_col1, #T_7096c_row0_col2, #T_7096c_row0_col3, #T_7096c_row0_col4, #T_7096c_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7096c_row1_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_7096c_row1_col2, #T_7096c_row2_col1 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_7096c_row1_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_7096c_row1_col4 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_7096c_row2_col0 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_7096c_row2_col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_7096c_row2_col4 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_7096c_row3_col1 {
#   background-color: #dedcdb;
#   color: #000000;
# }
# #T_7096c_row3_col2 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_7096c_row3_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_7096c_row4_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_7096c_row4_col1 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_7096c_row4_col2 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_7096c_row4_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# </style>
# <table id="T_7096c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >abv</th>
#       <th class="col_heading level0 col1" >taste</th>
#       <th class="col_heading level0 col2" >feel</th>
#       <th class="col_heading level0 col3" >look</th>
#       <th class="col_heading level0 col4" >smell</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7096c_level0_row0" class="row_heading level0 row0" >abv</th>
#       <td id="T_7096c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7096c_row0_col1" class="data row0 col1" >0.302774</td>
#       <td id="T_7096c_row0_col2" class="data row0 col2" >0.301149</td>
#       <td id="T_7096c_row0_col3" class="data row0 col3" >0.294412</td>
#       <td id="T_7096c_row0_col4" class="data row0 col4" >0.328565</td>
#     </tr>
#     <tr>
#       <th id="T_7096c_level0_row1" class="row_heading level0 row1" >taste</th>
#       <td id="T_7096c_row1_col0" class="data row1 col0" >0.302774</td>
#       <td id="T_7096c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7096c_row1_col2" class="data row1 col2" >0.805044</td>
#       <td id="T_7096c_row1_col3" class="data row1 col3" >0.654792</td>
#       <td id="T_7096c_row1_col4" class="data row1 col4" >0.780280</td>
#     </tr>
#     <tr>
#       <th id="T_7096c_level0_row2" class="row_heading level0 row2" >feel</th>
#       <td id="T_7096c_row2_col0" class="data row2 col0" >0.301149</td>
#       <td id="T_7096c_row2_col1" class="data row2 col1" >0.805044</td>
#       <td id="T_7096c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7096c_row2_col3" class="data row2 col3" >0.683654</td>
#       <td id="T_7096c_row2_col4" class="data row2 col4" >0.717882</td>
#     </tr>
#     <tr>
#       <th id="T_7096c_level0_row3" class="row_heading level0 row3" >look</th>
#       <td id="T_7096c_row3_col0" class="data row3 col0" >0.294412</td>
#       <td id="T_7096c_row3_col1" class="data row3 col1" >0.654792</td>
#       <td id="T_7096c_row3_col2" class="data row3 col2" >0.683654</td>
#       <td id="T_7096c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7096c_row3_col4" class="data row3 col4" >0.676526</td>
#     </tr>
#     <tr>
#       <th id="T_7096c_level0_row4" class="row_heading level0 row4" >smell</th>
#       <td id="T_7096c_row4_col0" class="data row4 col0" >0.328565</td>
#       <td id="T_7096c_row4_col1" class="data row4 col1" >0.780280</td>
#       <td id="T_7096c_row4_col2" class="data row4 col2" >0.717882</td>
#       <td id="T_7096c_row4_col3" class="data row4 col3" >0.676526</td>
#       <td id="T_7096c_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
beer_reviews_complete_df['style'].hist(figsize=(15,15), xrot=90)
# Out:
# <AxesSubplot:>

# %%
beer_reviews_complete_df.columns
# Out:
# Index(['beer_id', 'beer_name', 'brewery_id', 'state_beer', 'country_beer',
#        'style', 'abv', 'brewery_name', 'city', 'look', 'smell', 'taste',
#        'feel', 'overall', 'score'],
#       dtype='object')

# %%
# Distribution for beer look
x = beer_reviews_complete_df['look']
plt.hist(x, density = True, label = "look")
plt.legend()
plt.show()

# %%
# Distribution for beer smell
x = beer_reviews_complete_df['smell']
plt.hist(x, density = True, label = "smell")
plt.legend()
plt.show()

# %%
# Distribution for beer taste
x = beer_reviews_complete_df['taste']
plt.hist(x, density = True, label = "taste")
plt.legend()
plt.show()

# %%
# Distribution for beer feel
x = beer_reviews_complete_df['feel']
plt.hist(x, density = True, label = "feel")
plt.legend()
plt.show()

# %%
# Distribution for beer overall
x = beer_reviews_complete_df['overall']
plt.hist(x, density = True, label = "overall")
plt.legend()
plt.show()

# %%
# Distribution for beer score
x = beer_reviews_complete_df['score']
plt.hist(x, density = True, label = "score")
plt.legend()
plt.show()

# %%
# score from reviews are skewed to the left

# %%
# Distribution for beer abv
x = beer_reviews_complete_df['abv']
plt.hist(x, density = True, label = "abv")
plt.legend()
plt.show()
