# %%
# Import Dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# I converted the original excel file into a csv file but looks like it can't be coverted to DataFrame.

# %%
df = pd.read_csv("CensusProfile2016.csv")
df
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /var/folders/vb/vjm9gs5953s5qhprgwt1rmtm0000gn/T/ipykernel_46585/87418178.py in <module>
# ----> 1 df = pd.read_csv("CensusProfile2016.csv")
#       2 df
#
# ~/opt/anaconda3/envs/pythondata/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %% [markdown]
# The raw excel file then cleaned to keep only the ethnic origin based on the continent and then saved as a CSV file. The CSV file was importd and converted to DataFrame for analysis. The data can be filtered further based on the ML model selection.

# %%
df = pd.read_csv("Ethnic origin data (Cencus 2016).csv")
df
# Out:
#                                           Unnamed: 0  Toronto  Ward 1  Ward 2  \
# 0  Total - Ethnic origin for the population in pr...  2691665   60040   56295
# 1                  North American Aboriginal origins    35630     330     355
# 2                       Other North American origins   345705    4390    5410
# 3                                   European origins  1288850   10095   21600
# 4                                  Caribbean origins   165735    7895    5525
# 5          Latin, Central and South American origins   113820    3730    3995
# 6                                    African origins   146870    7740    8635
# 7                                      Asian origins  1079290   32640   19305
# 8                                    Oceania origins     5795      15      45
#
#    Ward 3  Ward 4  Ward 5  Ward 6  Ward 7  Ward 8  ...  Ward 39  Ward 40  \
# 0   52470   55395   69645   66690   52905   49850  ...    53015    63700
# ...
